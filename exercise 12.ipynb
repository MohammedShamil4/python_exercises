# %%
#create rectangle class with attribute l and b and method to find area and perimeter.compare 2 rectangle object by their area
class rectangle():
    def getrectangle(self,length,breadth):
        self.length=length
        self.breadth=breadth
    def area(self):
        return (self.breadth*self.length)
    def perimeter(self):
        return (self.breadth+self.length)*2
    
newrectangle=rectangle()
length=int(input("length"))
breadth=int(input("breadth"))
newrectangle.getrectangle(length,breadth)
print("area  1st rectangle",newrectangle.area())
print("perimeter 1st rectangle",newrectangle.perimeter())

print("\n")

newrectangle1=rectangle()
length=int(input("length"))
breadth=int(input("breadth"))
newrectangle1.getrectangle(length,breadth)
print("area 2nd rectangle",newrectangle1.area())
print("perimeter 2nd rectangle",newrectangle.perimeter())

r=newrectangle.area()
s=newrectangle1.area()

print("\n")

if r>s:
    print("area of rect  1 is greater ")
else:
    print("area of rect  2 is greater ")
# Out:
# length4
# breadth5
# area  1st rectangle 20
# perimeter 1st rectangle 18
#
#
# length3
# breadth4
# area 2nd rectangle 12
# perimeter 2nd rectangle 18
#
#
# area of rect  1 is greater

# %%
#class student.include details like rollno,name and class and display

class Student:
    def getData(self, rn, name, batch):
        Student.rn = rn
        Student.name = name
        Student.batch= batch
            
    def displayData(self):
        print ("Rollno  : ", Student.rn)
        print ("Name    : ", Student.name)
        print ("class   : ",Student.batch)
         
r = int (input("Enter the roll number: "))
name = input("Enter the name: ")
batch = input("Enter the batch: ")
 
print("\n")
s1 = Student()
s1.getData(r, name, batch)
s1.displayData()
# Out:
# Enter the roll number: 17
# Enter the name: shamil
# Enter the batch: mca
#
#
# Rollno  :  17
# Name    :  shamil
# class   :  mca

# %%
#class student.include details like rollno,name and class. assign initial values and display student details
class Student:
  def __init__(self, name, rollno,batch):
    self.name = name
    self.rollno = rollno
    self.batch = batch

  def detail(self):
    print("Name : " ,self.name)
    print("Rollno : " ,self.rollno)
    print("Batch : " ,self.batch)

n=input("enter name : ")
r=int(input("enter rollno. : "))
b=input("enter batch : ")
print("\n")
print("RECORDED DETAILS OF THE STUDENT IS  ")
p = Student(n, r,b)
p.detail()
# Out:
# enter name : Shamil
# enter rollno. : 17
# enter batch : MCA
#
#
# RECORDED DETAILS OF THE STUDENT IS
# Name :  Shamil
# Rollno :  17
# Batch :  MCA

# %%
#bank accnt with acc_number,name,type of and balance.write constructor and method to deposit at bank and withdraw an amt
class bank:
    def __init__(self,i,name,acc_no,acc_type):
        self.i=i
        self.name=name
        self.acc_no=acc_no
        self.acc_type=acc_type
    def display(self):
        print("Name         : ",self.name)
        print("Account_no   : ",self.acc_no)
        print("Account_type : ",self.acc_type)
        

class user:
    def __init__(self,i):
        self.b=0
        self.i=i
        
    def da(self):
        self.n=int(input("amount to be deposited : "))
        self.b=self.b+self.n
        print("main balance : ",self.b)
        
    def wa(self):
        self.amt=int(input("amount to withdraw : "))
        if self.b < self.amt:
            print("failed to process.... ")
        else:
            self.b-=self.amt
            print("main balance : ",self.b)
    def di(self):
        print("your main balance is : ",self.b)
        
e=bank(1,"SHAMIL","SBI8900","SAVINGS")

k=int(input("enter pincode"))
p=user(k)

if e.i==p.i:
    e.display()
    while(1):
        print("\n1.deposit \n2.withdraw \n3.balance \n4.exit")
        opt=int(input("enter an choice : "))
        if opt==1:
            p.da()
        
        elif opt==2:
            p.wa()
           
        elif opt==3:
            p.di()
            
        else:
            print("THANK YOU")
            print("EXITING.......")
            break
else:
    print("incorrect pincode")
# Out:
# enter pincode1
# Name         :  SHAMIL
# Account_no   :  SBI8900
# Account_type :  SAVINGS
#
# 1.deposit
# 2.withdraw
# 3.balance
# 4.exit
# enter an choice : 1
# amount to be deposited : 222
# main balance :  222
#
# 1.deposit
# 2.withdraw
# 3.balance
# 4.exit
# enter an choice : 1
# amount to be deposited : 2
# main balance :  224
#
# 1.deposit
# 2.withdraw
# 3.balance
# 4.exit
# enter an choice : 2
# amount to withdraw : 222
# main balance :  2
#
# 1.deposit
# 2.withdraw
# 3.balance
# 4.exit
# enter an choice : 2
# amount to withdraw : 3
# failed to process....
#
# 1.deposit
# 2.withdraw
# 3.balance
# 4.exit
# enter an choice : 3
# your main balance is :  2
#
# 1.deposit
# 2.withdraw
# 3.balance
# 4.exit
# enter an choice : 4
# THANK YOU
# EXITING.......

# %%
#class publisher derive class book from publisher with attribute title and author derive class det_book from book 
#with attribute total page and price .display info about det_book and book
class publisher:
    def __init__(self,authr):
        self.authr=authr
        
class book(publisher):
    def __init__(self,nm,authr):
        publisher.__init__(self,nm)
        self.title=nm
        print("author name : ",self.authr)
        print("title : ",self.title)
        
class det_book(book):
    def __init__(self,nm,authr,price,ttpg):
        publisher.__init__(self,authr)
        book.__init__(self,nm,authr)
        self.price=price
        self.totalpage=ttpg
        print("price : ",self.price)
        print("total pages : ",self.totalpage)
        

a=input("enter the title of book : ")
b=input("enter the author of book : ")
c=int(input("enter the price of book : "))
d=int(input("enter the totalpages of book : "))
print("\n")
s=det_book(a,b,c,d)
# Out:
# enter the title of book : LORD OF RINGS
# enter the author of book : John Ronald Reuel Tolkien
# enter the price of book : 850
# enter the totalpages of book : 1800
#
#
# author name :  LORD OF RINGS
# title :  LORD OF RINGS
# price :  850
# total pages :  1800
