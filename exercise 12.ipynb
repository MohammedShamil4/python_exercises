# %%
#12.1create rectangle class
class Rectangle:
    def rectlb(self,l,b):
        self.length=l
        self.breadth=b
    def area(self):
        return self.length*self.breadth
    def perimeeter(self):
        return 2*(self.length+self.breadth)
obj1=Rectangle()        
obj2=Rectangle()
l=int(input("Enter the length of rectangle 1:"))
b=int(input("Enter the breadth of rectangle 1:"))
l1=int(input("Enter the length of rectangle 2:"))
b1=int(input("Enter the breadth of rectangle 2:"))
obj1.rectlb(l,b)
obj2.rectlb(l1,b1)
area=obj1.area()
area1=obj2.area()
if area>area1:
    print("The area of 1st rectangle is greater")
    print("Area=",area)
    print("Perimeeter=",obj1.perimeeter())
    print("Difference in area : ",area-area1)
else:
    print("The area of 2nd rectangle is greater")
    print("Area=",area1)
    print("Perimeeter=",obj2.perimeeter())
    print("Difference in area : ",area1-area)
# Out:
# Enter the length of rectangle 1:4
# Enter the breadth of rectangle 1:2
# Enter the length of rectangle 2:5
# Enter the breadth of rectangle 2:3
# The area of 2nd rectangle is greater
# Area= 15
# Perimeeter= 16
# Difference in area :  7

# %%
#class publisher derive class book from publisher with attribute title and author derive class python from book 
#with attribute total page and price .display info about python  book
class publisher:
    def __init__(self,pubnm):
        self.pnm=pubnm
    def dis(self):
        print("Publisher Name : ",self.pnm)
class book(publisher):
    def __init__(self,pubnm,booknm,auther):
        self.bname=booknm
        self.ath=auther
        publisher.__init__(self,pubnm)
    def disp(self):
        print("\nName of Book : ",self.bname)
        print("Name of Auther : ",self.ath)
class python(book):
    def __init__(self,pn,tit,aut,price,n):
        self.price=price
        self.np=n
        book.__init__(self,pn,tit,aut)
    def display(self):
        print("\nPrice of Book : ",self.price)
        print("No.of pages : ",self.np)
            
pn=input("Enter Publisher name  : ")
bn=input("Enter Book Name  : ")   
auth=input("Enter Auther Name  : ")
r=input("Enter Rate of Book  : ")
n=input("Enter no.of pages  : ")
print("----------------------------------------")
f=python(pn,bn,auth,r,n)
f.dis()
f.disp()
f.display()
# Out:
# Enter Publisher name  : sam
# Enter Book Name  : book
# Enter Auther Name  : author
# Enter Rate of Book  : 2333
# Enter no.of pages  : 12
# ----------------------------------------
# Publisher Name :  sam
#
# Name of Book :  book
# Name of Auther :  author
#
# Price of Book :  2333
# No.of pages :  12

# %%
#12.5 create base class and 2child class
class person:
    def __init__(self,nam,cd):
        self.name=nam
        self.code=cd
        
class account(person):
    def __init__(self,pay,name,code):
        self.pay=pay
        person.__init__(self,name,code)
    def member_pay(self):
        print("payment : ",self.pay)
    
class admin(person):
    def __init__(self,exp,name,code):
        self.exp=exp
        person.__init__(self,name,code)
        
        
        
class employee(account,admin):
    
    def __init__(self,nm,cd,ex,pay):
        admin.__init__(self,ex,nm,cd)
        account.__init__(self,pay,nm,cd)
        
    def display(self):
        print("Employee Name : ",self.name)
        print("Employee code : ",self.code)
        print("Employee Experiance : ",self.exp)
        print("Employee payment : ",self.pay)
        
        
nm=input("Enter Employee name  : ")
cd=input("Enter emp code  : ")
ex=input("Enter emp experience  : ")
pay=input("Enter pay  : ")
print("----------------------------")
f=employee(nm,cd,ex,pay)
f.display()
# Out:
# Enter Employee name  : sam
# Enter emp code  : 12
# Enter emp experience  : 4
# Enter pay  : 4500
# ----------------------------
# Employee Name :  sam
# Employee code :  12
# Employee Experiance :  4
# Employee payment :  4500

# %%
#12.6 operator overloading"<"
class rectangle:
    def __init__(self,l,b):
        self.ar=l*b
    def __lt__(self,another):
        if self.ar<another.ar:
            print("2nd area is greater")
            print("difference : ",another.ar-self.ar)
            print("Area of 1st= ",self.ar)
            print("Area of 2nd= ",another.ar)
        else:
            print("1st area is greater")
            print("difference : ",self.ar-another.ar)
            print("Area of 1st= ",self.ar)
            print("Area of 2nd= ",another.ar)

l=int(input("Enter length of 1st rectangle  : "))
b=int(input("Enter breadth of 1st rectangle  : "))
l1=int(input("Enter length of 2nd rectangle  : "))
b1=int(input("Enter breadth of 2nd rectangle  : "))
print("-----------------------------------------")
r=rectangle(l,b)
r1=rectangle(l1,b1)
r<r1
# Out:
# Enter length of 1st rectangle  : 3
# Enter breadth of 1st rectangle  : 2
# Enter length of 2nd rectangle  : 4
# Enter breadth of 2nd rectangle  : 2
# -----------------------------------------
# 2nd area is greater
# difference :  2
# Area of 1st=  6
# Area of 2nd=  8

# %%
#12.7 operator overloading "+" add 2 time
class Time():
    def __init__(self,hour,minute,seconds):
        self.__h=hour
        self.__m=minute
        self.__s=seconds
    def __add__(self,time):
        sec=self.__s+time.__s
        mi=self.__m+time.__m
        hr=self.__h+time.__h
        if sec>=60:
            mi+=1
            sec-=60
        if mi>=60:
            hr+=1
            mi-=60
        
        print("total hours min secs")
        print(hr,"hour\t",mi,"min\t",sec,"seconds")
h=int(input("hour1 :"))
m=int(input("min1 :"))
s=int(input("sec1 :"))
print("-----------------")

h1=int(input("hour2 :"))
m1=int(input("min2 :"))
s1=int(input("sec2 :"))
print("-----------------")
f=Time(h,m,s)
f1=Time(h1,m1,s1) 
f+f1
# Out:
# hour1 :1
# min1 :30
# sec1 :10
# -----------------
# hour2 :2
# min2 :30
# sec2 :10
# -----------------
# total hours min secs
# 4 hour	 0 min	 20 seconds

# %%
#class student.include details like rollno,name and class and display

class Student:
    def getData(self, rn, name, batch):
        Student.rn = rn
        Student.name = name
        Student.batch= batch
            
    def displayData(self):
        print ("Rollno  : ", Student.rn)
        print ("Name    : ", Student.name)
        print ("class   : ",Student.batch)
         
r = int (input("Enter the roll number: "))
name = input("Enter the name: ")
batch = input("Enter the batch: ")
 
print("\n")
s1 = Student()
s1.getData(r, name, batch)
s1.displayData()
# Out:
# Enter the roll number: 12
# Enter the name: sam
# Enter the batch: mba
#
#
# Rollno  :  12
# Name    :  sam
# class   :  mba

# %%
#class student.include details like rollno,name and class. assign initial values and display student details
class Student:
  def __init__(self, name, rollno,batch):
    self.name = name
    self.rollno = rollno
    self.batch = batch

  def detail(self):
    print("Name : " ,self.name)
    print("Rollno : " ,self.rollno)
    print("Batch : " ,self.batch)

n=input("enter name : ")
r=int(input("enter rollno. : "))
b=input("enter batch : ")
print("\n")
print("RECORDED DETAILS OF THE STUDENT IS  ")
p = Student(n, r,b)
p.detail()
# Out:
# enter name : ram
# enter rollno. : 14
# enter batch : mca
#
#
# RECORDED DETAILS OF THE STUDENT IS
# Name :  ram
# Rollno :  14
# Batch :  mca

# %%
#bank accnt with acc_number,name,type of and balance.write constructor and method to deposit at bank and withdraw an amt
class bank:
    
    name=" SHAMIL "
    acc_no=" SBI58909 "
    acc_type=" SAVINGS "
    
    def __init__(self):
        self.b=0
        
    def display(self):
        print("Name         : ",self.name)
        print("Account_no   : ",self.acc_no)
        print("Account_type : ",self.acc_type)
        
        
    def da(self):
        self.n=int(input("amount to be deposited : "))
        self.b=self.b+self.n
        print("main balance : ",self.b)
        
    def wa(self):
        self.amt=int(input("amount to withdraw : "))
        if self.b < self.amt:
            print("failed to process.... ")
        else:
            self.b-=self.amt
            print("main balance : ",self.b)
    def di(self):
        print("your main balance is : ",self.b)


s=bank()
s.display()
while(1):
    print("\n1.deposit \n2.withdraw \n3.balance \n4.exit")
    opt=int(input("enter an choice : "))
    if opt==1:
        s.da()
    elif opt==2:
        s.wa()
    elif opt==3:
        s.di()
    else:
        print("THANK YOU")
        print("EXITING.......")
        break
# Out:
# Name         :   SHAMIL
# Account_no   :   SBI58909
# Account_type :   SAVINGS
#
# 1.deposit
# 2.withdraw
# 3.balance
# 4.exit
# enter an choice : 1
# amount to be deposited : 1000
# main balance :  1000
#
# 1.deposit
# 2.withdraw
# 3.balance
# 4.exit
# enter an choice : 2
# amount to withdraw : 3000
# failed to process....
#
# 1.deposit
# 2.withdraw
# 3.balance
# 4.exit
# enter an choice : 2
# amount to withdraw : 1500
# failed to process....
#
# 1.deposit
# 2.withdraw
# 3.balance
# 4.exit
# enter an choice : 2
# amount to withdraw : 500
# main balance :  500
#
# 1.deposit
# 2.withdraw
# 3.balance
# 4.exit
# enter an choice : 3
# your main balance is :  500
#
# 1.deposit
# 2.withdraw
# 3.balance
# 4.exit
# enter an choice : 1
# amount to be deposited : 200
# main balance :  700
#
# 1.deposit
# 2.withdraw
# 3.balance
# 4.exit
# enter an choice : 4
# THANK YOU
# EXITING.......
